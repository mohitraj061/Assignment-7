# %% [raw]
# Ques 1.) What is the name of the feature responsible for generating Regex objects ?
#
# Solution :
#
#
# The feature responsible for generating Regex objects, typically used for regular expression pattern matching and manipulation,
# depends on the programming language or library being used. Here are some commonly used features for generating Regex objects
# in different programming languages :
#
# * Python : The 're' module provides functions and methods for working with regular expressions. We can use the re.compile()
#            function to generate a Regex object from a given pattern.
#
# * Java : The java.util.regex package provides classes for working with regular expressions. We can use the Pattern.compile()
#          method to create a Regex object.
#
# * JavaScript : The RegExp object is built-in in JavaScript and allows you to work with regular expressions directly. We can
#             create a Regex object using the new RegExp() constructor or by using regular expression literals (e.g., /pattern/).
#
# * Ruby : In Ruby, regular expressions are built into the language syntax. We can create a Regex object by enclosing the
#          pattern in forward slashes (e.g., /pattern/).
#
# * .NET (C#) : The System.Text.RegularExpressions namespace provides classes for working with regular expressions in C#.
#               We can use the Regex class to create a Regex object by calling the constructor with the desired pattern.
#
# Please note that the specific implementation and syntax may vary slightly depending on the programming language or library
# being used, but the concept of generating a Regex object remains consistent.

# %% [raw]
# Ques 2.) Why do raw strings often appear in Regex objects ?
#
# Solution :
#
# Raw strings are often used in regular expressions to avoid excessive use of escape characters. In many programming languages,
# including Python, backslashes () are commonly used as escape characters. However, in regular expressions, backslashes are also
# used as metacharacters to give special meaning to certain characters or character sequences.
#
# By using a raw string (prefixed with the letter 'r'), we can create a string literal in which backslashes are treated as
# literal characters rather than escape characters. This makes it easier to write and read regular expressions because we don't
# need to double escape special characters.
#
# For example, let's say we want to match a literal backslash followed by a lowercase 'n' using a regular expression. Without
# using a raw string, we would need to escape the backslash itself and the 'n', resulting in four backslashes :
#
#     pattern = '\\\\n'
#
# However, by using a raw string, we can write the pattern more clearly without the need for extra escaping :
#
#     pattern = r'\\n'
#
# The raw string notation allows us to write regular expressions in a more concise and readable way, reducing the clutter of
# excessive backslashes. It is especially useful when dealing with complex patterns that contain many special characters or when
# working with file paths, URLs, or other string formats that frequently include backslashes.

# %% [raw]
# Ques 3.) What is the return value of the search() method ?
#
# Solution :
#
# The search() method in regular expression implementations typically returns a match object if a match is found, or None if no
# match is found. The specific details of the returned match object may vary depending on the programming language or library
# being used.
#
# When a match is found, the match object contains information about the match, such as the matched string, the starting and
# ending positions of the match, and any captured groups within the pattern.
#
# Here's an example in Python :
#
# import re
#
# pattern = r'apple'
# text = 'I have an apple and a banana.'
#
# match = re.search(pattern, text)
# if match:
#     print('Match found:', match.group())
# else:
#     print('No match found.')
#
# In this example, the search() method is used to find the first occurrence of the word "apple" in the given text. If a match
# is found, the match object's group() method is called to retrieve the matched string. If no match is found, the output will
# be "No match found."
#
# It's important to handle the case where search() returns None to account for situations when no match is found in the input
# string.

# %% [raw]
# Ques 4.) From a Match item, how do you get the actual strings that match the pattern ?
#
# Solution :
#
# To retrieve the actual strings that match the pattern from a Match object, we can use the group() method. The group() method,
# without any arguments, returns the entire matched string. We can also use the method with an argument to retrieve specific
# captured groups within the pattern if our regular expression includes capturing groups.
#
# Here's an example in Python :
#
# import re
#
# pattern = r'(\d+)-(\d+)-(\d+)'  # Pattern with capturing groups
# text = 'Date: 2023-06-30'
#
# match = re.search(pattern, text)
# if match:
#     # Retrieve the entire matched string
#     full_match = match.group(0)
#     print('Full match:', full_match)
#
#     # Retrieve the matched strings of each capturing group
#     group1 = match.group(1)
#     group2 = match.group(2)
#     group3 = match.group(3)
#     print('Group 1:', group1)
#     print('Group 2:', group2)
#     print('Group 3:', group3)
#
# In this example, the regular expression pattern captures three groups of digits separated by hyphens. The search() method finds
# the pattern in the given text, and then the group() method is used to retrieve the matched strings.
#
# The group(0) call returns the entire matched string, while group(1), group(2), and group(3) retrieve the matched strings of the
# first, second, and third capturing groups, respectively.
#
# Note that the capturing groups are defined using parentheses in the regular expression pattern. The group() method allows us
# to access the captured groups by their respective indices (starting from 1) within the pattern.

# %% [raw]
# Ques 5.) In the regex which created from the r'(\d\d\d)-(\d\d\d-\d\d\d\d)', what does group zero cover ? Group 2 ? Group 1 ?
#
# Solution :
#
# In the regular expression r'(\d\d\d)-(\d\d\d-\d\d\d\d)', the groups are defined by the parentheses. Let's break down the groups:
#
# Group 0 : The entire matched string. It covers the entire pattern match, including both capturing groups.
# Group 1 : The first capturing group (\d\d\d). It captures three consecutive digits.
# Group 2 : The second capturing group (\d\d\d-\d\d\d\d). It captures a three-digit block followed by a hyphen and a four-digit
#           block.
#
# Here's an example in Python to demonstrate accessing the groups :
#
# import re
#
# pattern = r'(\d\d\d)-(\d\d\d-\d\d\d\d)'
# text = 'Phone number: 123-456-7890'
#
# match = re.search(pattern, text)
# if match:
#     full_match = match.group(0)
#     group1 = match.group(1)
#     group2 = match.group(2)
#
#     print('Full match:', full_match)
#     print('Group 1:', group1)
#     print('Group 2:', group2)
#
# Ouput :
#
#     Full match : 123-456-7890
#     Group 1 : 123
#     Group 2 : 456-7890
#
# In this example, group(0) represents the entire matched string '123-456-7890'. group(1) corresponds to '123', which is the
# first capturing group, and group(2) corresponds to '456-7890', which is the second capturing group.

# %% [raw]
# Ques 6.) In standard expression syntax, parentheses and intervals have distinct meanings. How can you tell a regex that you
#          want it to fit real parentheses and periods ?
#
# Solution :
#
# To specify that we want a regular expression to match literal parentheses and periods, we can use the backslash () character
# to escape them. In regular expression syntax, the backslash is used to indicate that the following character should be treated
# as a literal character rather than a metacharacter with special meaning.
#
# Here's an example :
#
# 1.) Matching literal parentheses :
#
# To match literal parentheses, we can use \( to match an opening parenthesis and \). Here's an example that looks for a string
# containing a pair of parentheses :
#
# import re
#
# pattern = r'\(.*\)'
# text = 'Example (with parentheses)'
#
# match = re.search(pattern, text)
# if match:
#     print('Match found:', match.group())
# else:
#     print('No match found.')
#
# Output :
#
#     Match found : (with parentheses)
#
# 2.) Matching a literal period :
#
# To match a literal period, we can use \.. Here's an example that looks for a string containing a period :
#
# import re
#
# pattern = r'\w+\.'
# text = 'This sentence ends with a period.'
#
# match = re.search(pattern, text)
# if match:
#     print('Match found:', match.group())
# else:
#     print('No match found.')
#
# Output :
#
#     Match found : period.
#
# In both cases, the backslash before the parentheses or the period tells the regular expression engine to treat them as literal
# characters rather than metacharacters with their usual meanings.

# %% [raw]
# Ques 7.) The findall() method returns a string list or a list of string tuples. What causes it to return one of the
#          two options ?
#
# Solution :
#
# The findall() method in regular expression implementations can return either a list of strings or a list of string tuples,
# depending on the presence of capturing groups in the regular expression pattern.
#
# When the pattern in findall() does not contain any capturing groups (i.e., no parentheses), it returns a list of strings.
# Each element in the list represents a non-overlapping match found in the input text.
#
# Here's an example that demonstrates findall() returning a list of strings :
#
# import re
#
# pattern = r'\d+'
# text = 'I have 123 apples and 456 bananas.'
#
# matches = re.findall(pattern, text)
# print(matches)
#
# Output :
#
#     ['123', '456']
#
# In this case, the pattern \d+ matches one or more consecutive digits. Since there are no capturing groups in the pattern,
# findall() returns a list of strings representing the matched digits.
#
# However, when the pattern includes one or more capturing groups (defined with parentheses), findall() returns a list of string
# tuples. Each tuple represents a match, and each element in the tuple corresponds to a capturing group within the pattern.
#
# Here's an example that demonstrates findall() returning a list of string tuples :
#
# import re
#
# pattern = r'(\d+)-(\d+)'
# text = 'Phone numbers: 123-456, 789-012'
#
# matches = re.findall(pattern, text)
# print(matches)
#
# Output :
#
#     [('123', '456'), ('789', '012')]
#
# In this case, the pattern (\d+)-(\d+) matches digit pairs separated by a hyphen. Since there are two capturing groups,
# findall() returns a list of string tuples, where each tuple contains the matched strings of the capturing groups.
#
# So, the presence or absence of capturing groups in the pattern determines whether findall() returns a list of strings or a
# list of string tuples.

# %% [raw]
# Ques 8.) In standard expressions, what does the | character mean ?
#
# Solution :
#
# In regular expressions, the vertical bar or pipe character (|) is used to denote an alternation or choice between multiple
# patterns. It is known as the "OR" operator.
#
# The | character separates two or more alternative patterns and matches any of the patterns it separates. It allows us to
# specify multiple options, and if any of the options match, the overall pattern is considered a match.
#
# Here's an example to illustrate the usage of the | character :
#
# import re
#
# pattern = r'cat|dog'
# text = 'I have a cat and a dog.'
#
# matches = re.findall(pattern, text)
# print(matches)
#
# Output :
#
#     ['cat', 'dog']
#
# In this example, the pattern cat|dog matches either the word "cat" or the word "dog". When using findall(), it returns a list
# of all non-overlapping matches found in the text. In this case, it matches both "cat" and "dog" separately.
#
# The | character can also be used with more than two patterns :
#
# import re
#
# pattern = r'apple|banana|cherry'
# text = 'I like banana.'
#
# matches = re.findall(pattern, text)
# print(matches)
#
# Ouput :
#
#     ['banana']
#
# In this example, the pattern apple|banana|cherry matches either "apple", "banana", or "cherry". It finds a match for "banana"
# in the given text.
#
# So, the | character in regular expressions allows us to specify multiple options or choices, matching any one of the provided
# patterns.

# %% [raw]
# Ques 9.) In regular expressions, what does the character stand for ?
#
# Solution :
#
# Something wrong in the question please check!

# %% [raw]
# Ques 10.) In regular expressions, what is the difference between the + and * characters ?
#
# Solution :
#
# In regular expressions, the "+" and "*" characters are quantifiers that specify the number of occurrences of the preceding
# element or group in the pattern.
#
# 1.) "+" Quantifier :
#
#     The "+" quantifier indicates that the preceding element or group must occur one or more times.
#
#     For eg , the pattern "a+" matches one or more consecutive occurrences of the letter "a". Here are some examples of how
#     it behaves :
#
#     "a" matches.
#     "aa" matches.
#     "aaa" matches.
#     "b" does not match.
#     "ab" matches the "a" part.
#
# 2.) "*" Quantifier :
#
#     The "*" quantifier indicates that the preceding element or group can occur zero or more times. It allows for optional
#     matches.
#
#     For eg , the pattern "a*" matches zero or more occurrences of the letter "a". Here are some examples :
#
#     "a" matches.
#     "aa" matches.
#     "aaa" matches.
#     "b" matches (zero occurrences of "a").
#     "ab" matches the "a" part.
#
# In summary:
#
# "+" requires at least one occurrence of the preceding element or group.
# "*" allows zero or more occurrences of the preceding element or group.
#
# It's important to note that the "+" and "*" quantifiers are "greedy" by default, meaning they match as many occurrences as
# possible. If we want a "non-greedy" match to find the shortest possible match, we can use the "+?" or "*?" forms.

# %% [raw]
# Ques 11.) What is the difference between {4} and {4,5} in regular expression ?
#
# Solution :
#
# In regular expressions, the expressions {4} and {4,5} are both used as quantifiers to specify the exact number of occurrences
# of the preceding element or group. However, they differ in their exact matching requirements.
#
# 1.) {4} Quantifier :
#
#     The {4} quantifier specifies that the preceding element or group must occur exactly four times.
#
#     For eg, the pattern "a{4}" matches exactly four consecutive occurrences of the letter "a". Here are some examples :
#
#     "aaaa" matches.
#     "aaaaa" does not match.
#     "aa" does not match.
#
#     The {4} quantifier ensures that the preceding element is repeated exactly four times for a match to occur.
#
# 2.) {4,5} Quantifier :
#
#     The {4,5} quantifier specifies a range for the number of occurrences of the preceding element or group. It allows for a
#     minimum and maximum number of repetitions.
#
#     For eg, the pattern "a{4,5}" matches between four and five consecutive occurrences of the letter "a".
#     Here are some examples:
#
#     "aaaa" matches.
#     "aaaaa" matches.
#     "aaaaaa" does not match.
#     "aa" does not match.
#
#     The {4,5} quantifier allows for flexibility by allowing the preceding element to occur between four and five times,
#     inclusive.
#
# In summary:
#
# {4} specifies exactly four occurrences of the preceding element or group.
# {4,5} specifies a range of four to five occurrences of the preceding element or group.
#
# These quantifiers provide control over the specific number of repetitions required for a match in regular expressions.

# %% [raw]
# Ques 12.) What do you mean by the \d, \w, and \s shorthand character classes signify in regular expressions ?
#
# Solution :
#
# In regular expressions, the shorthand character classes \d, \w, and \s are predefined character classes that represent certain
# groups of characters :
#
# 1.) \d : Matches any digit character.
#
#     * Equivalent to the character set [0-9].
#     * It represents any single digit from 0 to 9.
#
# 2.) \w : Matches any word character.
#
#     * Equivalent to the character set [a-zA-Z0-9_].
#     * It represents any alphanumeric character (letters from a to z, both lowercase and uppercase, digits from 0 to 9),
#       and the underscore _.
#
# 3.) \s : Matches any whitespace character.
#
#     * Equivalent to the character set [\t\n\f\r\p{Z}].
#     * It represents spaces, tabs, newlines, carriage returns, and other whitespace characters.
#
# Here are some examples to illustrate the usage of these shorthand character classes :
#
# import re
#
# text = 'The number is 123 and the _word_ has spaces.'
#
# # Using \d to match a digit
# digits = re.findall(r'\d', text)
# print('Digits:', digits)  # Output: ['1', '2', '3']
#
# # Using \w to match word characters
# word_chars = re.findall(r'\w', text)
# print('Word characters:', word_chars)
# # Output: ['T', 'h', 'e', 'n', 'u', 'm', 'b', 'e', 'r', 'i', 's', '1', '2', '3', 'a', 'n', 'd', 't', 'h', 'e', '_', 'w', 'o', 'r', 'd', '_', 'h', 'a', 's', 's', 'p', 'a', 'c', 'e', 's']
#
# # Using \s to match whitespace characters
# whitespace_chars = re.findall(r'\s', text)
# print('Whitespace characters:', whitespace_chars)  # Output: [' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# In this example, the text is searched using different regular expressions with \d, \w, and \s. The resulting matches
# demonstrate the characters that fall into each shorthand character class.
#
# These shorthand character classes provide a convenient way to match common character types without explicitly listing all the
# individual characters in a set.

# %% [raw]
# Ques 14.) What is the difference between .*? and .*    ?
#
# Solution :
#
# The difference between .*? and .* lies in their behavior as quantifiers in regular expressions.
#
# 1.) .*? : Lazy or non-greedy match
#
#     The .*? is a non-greedy quantifier. It matches as little as possible while still allowing the overall pattern to match.
#     The .*? quantifier matches zero or more occurrences of any character (except newline characters) but prefers the shortest
#     match.
#     It stops matching as soon as the next part of the pattern can be matched.
#
# 2.) .* : Greedy match
#
#     The .* is a greedy quantifier. It matches as much as possible while still allowing the overall pattern to match.
#     The .* quantifier matches zero or more occurrences of any character (except newline characters) and prefers the longest
#     match.
#     It keeps matching until the next part of the pattern cannot be matched anymore.
#
# Here's an example to demonstrate the difference :
#
# import re
#
# text = 'Example text with some words.'
#
# # Using .*? (non-greedy match)
# pattern1 = r'wo.*?s'
# match1 = re.search(pattern1, text)
# print('Non-greedy match:', match1.group())  # Output: 'word'
#
# # Using .* (greedy match)
# pattern2 = r'wo.*s'
# match2 = re.search(pattern2, text)
# print('Greedy match:', match2.group())  # Output: 'words'
#
# In this example, the pattern wo.*?s and wo.*s are used to match a substring that starts with "wo" and ends with "s". However,
# they behave differently due to the quantifiers used.
#
# With .*?, the non-greedy match, the shortest match is preferred. It matches "wo" and stops as soon as it finds the first
# occurrence of "s", resulting in the match "word".
#
# With .*, the greedy match, the longest match is preferred. It matches "wo" and continues matching until the last occurrence of
# "s" in the text, resulting in the match "words".
#
# So, the difference between .*? and .* lies in the matching behavior, where .*? prefers the shortest match (lazy) and .* prefers
# the longest match (greedy).

# %% [raw]
# Ques 15.) What is the syntax for matching both numbers and lowercase letters with a character class ?
#
# Solution :
#
# To match both numbers and lowercase letters using a character class in regular expressions, we can use the range notation
# within the character class.
#
# The syntax for matching numbers (0-9) and lowercase letters (a-z) with a character class is [0-9a-z].
#
# Here's an example to illustrate the usage :
#
# import re
#
# text = 'abc123xyz456'
#
# pattern = r'[0-9a-z]+'
# matches = re.findall(pattern, text)
# print(matches)  # Output: ['abc', '123', 'xyz', '456']
#
# In this example, the pattern [0-9a-z]+ is used to match one or more occurrences of either a digit (0-9) or a lowercase letter
# (a-z). The + quantifier is added to match multiple characters in a row.
#
# The resulting matches are ['abc', '123', 'xyz', '456'], which represent the substrings that consist of numbers or lowercase
# letters.
#
# By using the range notation [0-9a-z] within the character class, we can create a pattern that matches both numbers and
# lowercase letters.

# %% [raw]
# Ques 16.) What is the procedure for making a normal expression in regax case insensitive ?
#
# Solution :
#
# To make a regular expression case-insensitive in Python, we can use the re.IGNORECASE flag or the re.I flag. These flags can
# be passed as an argument to the various functions of the re module to perform case-insensitive matching.
#
# Here's an example of how to create a case-insensitive regular expression :
#
# import re
#
# text = 'Hello World'
# pattern = r'hello'
# matches = re.findall(pattern, text, re.IGNORECASE)
# print(matches)  # Output: ['Hello']
#
# In this example, the regular expression pattern hello is matched against the text Hello World. By including the re.IGNORECASE
# flag as the third argument in the re.findall() function, the matching is performed in a case-insensitive manner.
#
# Alternatively, we can use the shorthand flag re.I instead of re.IGNORECASE :
#
# matches = re.findall(pattern, text, re.I)
#
# Both approaches achieve the same result of making the regular expression case-insensitive. The flag instructs the regular
# expression engine to ignore the distinction between uppercase and lowercase letters during the matching process.
#
# By utilizing the re.IGNORECASE flag or re.I flag when calling the appropriate re module functions, we can easily create
# case-insensitive regular expressions in Python.

# %% [raw]
# Ques 17.) What does the . character normally match ?
#           What does it match if re.DOTALL is passed as 2nd argument in re.compile() ?
#
# Solution :
#
# In regular expressions, the dot (.) character normally matches any character except for a newline character (\n). However,
# when the re.DOTALL flag is passed as the second argument in the re.compile() function or used with other re module functions,
# the dot (.) character matches any character, including newline characters.
#
# Here's an example to illustrate the difference :
#
# import re
#
# text = 'Hello\nWorld'
#
# # Without re.DOTALL
# pattern1 = r'.+'
# matches1 = re.findall(pattern1, text)
# print(matches1)  # Output: ['Hello']
#
# # With re.DOTALL
# pattern2 = r'.+'
# regex = re.compile(pattern2, re.DOTALL)
# matches2 = regex.findall(text)
# print(matches2)  # Output: ['Hello\nWorld']
#
# In the example above, the text contains a newline character (\n) between "Hello" and "World".
#
# * Without using re.DOTALL, the pattern .+ matches any character except for a newline character. Therefore, the match stops
#   at the newline character, and the resulting match is "Hello".
#
# * When re.DOTALL is used as the second argument in re.compile(), or with other re module functions, the dot (.) character
#   matches any character, including newline characters. Thus, the pattern .+ matches the entire string "Hello\nWorld".
#
# By using re.DOTALL, we can modify the behavior of the dot (.) character in regular expressions to match any character,
# including newline characters.

# %% [raw]
# Ques 18.) If numReg = re.compile(r'\d+'), what will numRegex.sub('X','11 drummers, 10 pipers, five rings, 4 hen') return ?
#
# Solution :
#
# If numReg = re.compile(r'\d+'), then numReg.sub('X', '11 drummers, 10 pipers, five rings, 4 hen') will return the string
# 'X drummers, X pipers, five rings, X hen'.
#
# Let's break down the code to understand the result :
#
# import re
#
# numReg = re.compile(r'\d+')
# result = numReg.sub('X', '11 drummers, 10 pipers, five rings, 4 hen')
# print(result)  # Output : 'X drummers, X pipers, five rings, X hen'
#
#
# In this code, the regular expression pattern r'\d+' is used to match one or more digit characters. The numReg.sub('X', text)
# function replaces all matches of the pattern in the provided text with the string 'X'.
#
# The input string is '11 drummers, 10 pipers, five rings, 4 hen'. The numbers "11", "10", and "4" in the string match the
# \d+ pattern and are replaced with the string 'X', resulting in the final output : 'X drummers, X pipers, five rings, X hen'.
#
# The sub() function is used to perform substitution in regular expressions, and in this case, it replaces all occurrences of
# digits with the letter 'X' in the input string.

# %% [raw]
# Ques 19). What does passing re.VERBOSE as the 2nd argument to re.compile() allow to do ?
#
# Solution :
#
# Passing re.VERBOSE as the second argument to re.compile() allows us to use verbose mode in regular expressions. Verbose mode
# enables us to write more readable and organized regular expressions by allowing the use of whitespace and comments within the
# pattern.
#
# Here's an example to illustrate the usage of re.VERBOSE :
#
# import re
#
# pattern = r'''
#     ^               # Start of the string
#     [A-Z0-9._%+-]+  # Username
#     @               # @ symbol
#     [A-Z0-9.-]+     # Domain name
#     \.              # Dot
#     [A-Z]{2,}       # Top-level domain (e.g., .com, .org)
#     $               # End of the string
#     '''
#
# email_regex = re.compile(pattern, re.VERBOSE)
#
# # Test the pattern
# email1 = 'john.doe@example.com'
# email2 = 'invalid.email@123'
# match1 = email_regex.match(email1)
# match2 = email_regex.match(email2)
#
# print(match1 is not None)  # Output : True
# print(match2 is not None)  # Output : False
#
# In this example, the regular expression pattern for matching email addresses is written in verbose mode using the re.VERBOSE
# flag. The pattern is written across multiple lines and includes comments to explain each part of the pattern.
#
# By using re.VERBOSE, we can add whitespace, line breaks, and comments to make the regular expression more readable and
# understandable. It helps to improve the clarity and maintainability of complex regular expressions.
#
# Note that when using re.VERBOSE, any whitespace characters (except those included in character classes or escaped) and comments
# are ignored by the regular expression engine, so they don't affect the pattern matching.

# %% [raw]
# Ques 20.) How would you write a regex that match a number with comma for every three digits ? It must match the given
#           following :
#
#           '42'
#           '1,234'
#           '6,368,745'
#
#           but not the following :
#
#           '12,34,567'(which has only two digits between the commas)
#           '1234'(which lacks commas)
#
# Solution :
#
# To write a regular expression that matches numbers with commas for every three digits, we can use the following pattern :
#
# import re
#
# pattern = r'^\d{1,3}(,\d{3})*$'
#
# text1 = '42'
# text2 = '1,234'
# text3 = '6,368,745'
# text4 = '12,34,567'
# text5 = '1234'
#
# match1 = re.match(pattern, text1)
# match2 = re.match(pattern, text2)
# match3 = re.match(pattern, text3)
# match4 = re.match(pattern, text4)
# match5 = re.match(pattern, text5)
#
# print(match1 is not None)  # Output : True
# print(match2 is not None)  # Output : True
# print(match3 is not None)  # Output : True
# print(match4 is not None)  # Output : False
# print(match5 is not None)  # Output : False
#
# In this example, the pattern '^\d{1,3}(,\d{3})*$' is used to match numbers with commas for every three digits. Let's break
# down the pattern :
#
# * '^' and '$' anchor the pattern to match the entire string from start to end.
# * \d{1,3} matches one to three digits at the beginning of the string.
# * (,\d{3})* matches zero or more occurrences of a comma followed by exactly three digits.
# * The * quantifier allows for multiple repetitions of (,\d{3}).
#
# The provided test cases demonstrate the matching behavior :
#
# * '42' matches because it consists of a single two-digit number.
# * '1,234' matches because it contains a three-digit number followed by a comma and another three-digit number.
# * '6,368,745' matches because it contains multiple three-digit numbers separated by commas.
# * '12,34,567' does not match because it has only two digits between the commas.
# * '1234' does not match because it lacks commas.
#
# By using the pattern '^\d{1,3}(,\d{3})*$', we can match numbers with commas for every three digits while satisfying the given
# requirements.

# %% [raw]
# ques 21.) How would you write a regex that matches the full name of someone whose last name is Watanabe ? You can assume that
#           the first name that comes before it will always be one word that begins with a capital letter. The regex must match
#           the following :
#
#           'Haruto Watanabe'
#           'Alice Watanabe'
#           'RoboCop Watanabe'
#
#           but not the following :
#
#           'haruto Watanabe'(where the first name is not capitalized)
#           'Mr. Watanabe'(where the preceding word has a nonletter character)
#           'Watanabe'(which has no first name)
#           'Haruto watanabe'(where Watanabe is not capitalized)
#
# Solution :
#
# To write a regular expression that matches the full name of someone whose last name is "Watanabe" and satisfies the given
# conditions, we can use the following pattern :
#
# import re
#
# pattern = r'^[A-Z][a-zA-Z]* Watanabe$'
#
# text1 = 'Haruto Watanabe'
# text2 = 'Alice Watanabe'
# text3 = 'RoboCop Watanabe'
# text4 = 'haruto Watanabe'
# text5 = 'Mr. Watanabe'
# text6 = 'Watanabe'
# text7 = 'Haruto watanabe'
#
# match1 = re.match(pattern, text1)
# match2 = re.match(pattern, text2)
# match3 = re.match(pattern, text3)
# match4 = re.match(pattern, text4)
# match5 = re.match(pattern, text5)
# match6 = re.match(pattern, text6)
# match7 = re.match(pattern, text7)
#
# print(match1 is not None)  # Output : True
# print(match2 is not None)  # Output : True
# print(match3 is not None)  # Output : True
# print(match4 is not None)  # Output : False
# print(match5 is not None)  # Output : False
# print(match6 is not None)  # Output : False
# print(match7 is not None)  # Output : False
#
#
# In this example, the pattern ^[A-Z][a-zA-Z]* Watanabe$ is used to match the full name with the last name "Watanabe".
# Let's break down the pattern :
#
# * '^' and '$'' anchor the pattern to match the entire string from start to end.
# * [A-Z] matches the first character of the first name, which must be an uppercase letter.
# * [a-zA-Z]* matches zero or more lowercase or uppercase letters, allowing for additional characters in the first name.
# * (a space) matches the space between the first name and the last name.
# * Watanabe matches the last name "Watanabe".
#
# The provided test cases demonstrate the matching behavior :
#
# * 'Haruto Watanabe' matches because the first name "Haruto" starts with a capital letter and the last name is "Watanabe".
# * 'Alice Watanabe' matches because the first name "Alice" starts with a capital letter and the last name is "Watanabe".
# * 'RoboCop Watanabe' matches because the first name "RoboCop" starts with a capital letter and the last name is "Watanabe".
# * 'haruto Watanabe' does not match because the first name is not capitalized.
# * 'Mr. Watanabe' does not match because the preceding word has a non-letter character.
# * 'Watanabe' does not match because it lacks a first name.
# * 'Haruto watanabe' does not match because the last name "Watanabe" is not capitalized.
#
# By using the pattern ^[A-Z][a-zA-Z]* Watanabe$, we can match the full name with the last name "Watanabe" while satisfying
# the given conditions.

# %% [raw]
# Ques 22.) How would you write a regex that matches a sentence where the first word is either Alice, Bob, or Carol; the second
#           word is either eats, pets, or throws; the third word is apples, cats, or baseballs; and the sentence ends with a
#           period ? This regex should be case-insensitive. It must match the following :
#
#           'Alice eats apples.'
#           'Bob pets cats.'
#           'Carol throws baseballs.'
#           'Alice throws Apples.'
#           'BOB EATS CATS.'
#
#           but not the following :
#
#           'RoboCop eats apples.'
#           'ALICE THROWS FOOTBALLS.'
#           'Carol eats 7 cats.'
#
# Solution :
#
# To write a case-insensitive regular expression that matches a sentence with specific words in a certain order, we can use the
# following pattern :
#
# import re
#
# pattern = r'^(Alice|Bob|Carol) (eats|pets|throws) (apples|cats|baseballs)\.$'
#
# text1 = 'Alice eats apples.'
# text2 = 'Bob pets cats.'
# text3 = 'Carol throws baseballs.'
# text4 = 'Alice throws Apples.'
# text5 = 'BOB EATS CATS.'
# text6 = 'RoboCop eats apples.'
# text7 = 'ALICE THROWS FOOTBALLS.'
# text8 = 'Carol eats 7 cats.'
#
# match1 = re.match(pattern, text1, re.IGNORECASE)
# match2 = re.match(pattern, text2, re.IGNORECASE)
# match3 = re.match(pattern, text3, re.IGNORECASE)
# match4 = re.match(pattern, text4, re.IGNORECASE)
# match5 = re.match(pattern, text5, re.IGNORECASE)
# match6 = re.match(pattern, text6, re.IGNORECASE)
# match7 = re.match(pattern, text7, re.IGNORECASE)
# match8 = re.match(pattern, text8, re.IGNORECASE)
#
# print(match1 is not None)  # Output : True
# print(match2 is not None)  # Output : True
# print(match3 is not None)  # Output : True
# print(match4 is not None)  # Output : True
# print(match5 is not None)  # Output : True
# print(match6 is not None)  # Output : False
# print(match7 is not None)  # Output : False
# print(match8 is not None)  # Output : False
#
#
# In this example, the pattern ^(Alice|Bob|Carol) (eats|pets|throws) (apples|cats|baseballs)\.$ is used to match a sentence
# with specific words in a particular order. Let's break down the pattern :
#
# * '^' and '$' anchor the pattern to match the entire string from start to end.
# * (Alice|Bob|Carol) matches either "Alice", "Bob", or "Carol" as the first word.
# * (eats|pets|throws) matches either "eats", "pets", or "throws" as the second word.
# * (apples|cats|baseballs) matches either "apples", "cats", or "baseballs" as the third word.
# * \. matches a period character (.) to indicate the end of the sentence.
#
# The re.IGNORECASE flag is used to make the pattern case-insensitive, allowing the words to match regardless of their
# capitalization.
#
# The provided test cases demonstrate the matching behavior :
#
# * 'Alice eats apples.' matches because it follows the specified pattern and the words are in the correct order.
# * 'Bob pets cats.' matches for the same reason.
# * 'Carol throws baseballs.' matches as well.
# * 'Alice throws Apples.' matches because the pattern is case-insensitive.
# * 'BOB EATS CATS.' matches because the pattern is case-insensitive.
# * 'RoboCop eats apples.' does not match because the first word is not "Alice", "Bob", or "Carol".
# * 'ALICE THROWS FOOTBALLS.' does not match because the second and third words do not match the specified options.
# * 'Carol eats 7 cats.' does not match because the third word is "7 cats" instead of "apples", "cats", or "baseballs".
#
# By using the pattern `^(Alice|Bob|Carol) (eats|pets|throws) (apples|cats|
